# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
np.random.seed(42)
torch.manual_seed(42)

# %%
# 时间步
t = np.arange(0, 300)

# 构造时间序列：趋势 + 周期 + 噪声
series = 0.03 * t + np.sin(0.2 * t) + 0.3 * np.random.randn(len(t))

print("前 10 个数据：")
print(series[:10])

print("序列长度：", len(series))
# Out:
# 前 10 个数据：
# [0.14901425 0.18719004 0.6437249  1.11155143 0.76711008 0.9212299
#  1.58580293 1.42568015 1.09873129 1.40661564]
# 序列长度： 300

# %%
plt.figure(figsize=(10, 4))
plt.plot(t, series)
plt.title("Original Time Series")
plt.xlabel("Time")
plt.ylabel("Value")
plt.grid(True)
plt.show()

# %%
def create_sequences(series, window_size):
    X = []
    y = []

    for i in range(len(series) - window_size):
        X.append(series[i:i + window_size])
        y.append(series[i + window_size])

    return np.array(X), np.array(y)

# %%
window_size = 10

X, y = create_sequences(series, window_size)

print("X shape:", X.shape)
print("y shape:", y.shape)

print("第一个输入样本：")
print(X[0])

print("第一个标签：")
print(y[0])
# Out:
# X shape: (290, 10)
# y shape: (290,)
# 第一个输入样本：
# [0.14901425 0.18719004 0.6437249  1.11155143 0.76711008 0.9212299
#  1.58580293 1.42568015 1.09873129 1.40661564]
# 第一个标签：
# 1.070272118981943

# %%
X = X.reshape(X.shape[0], X.shape[1], 1)

print("调整后的 X shape:", X.shape)
# Out:
# 调整后的 X shape: (290, 10, 1)

# %%
train_size = int(len(X) * 0.8)

X_train = X[:train_size]
y_train = y[:train_size]

X_test = X[train_size:]
y_test = y[train_size:]

print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (232, 10, 1)
# y_train: (232,)
# X_test: (58, 10, 1)
# y_test: (58,)

# %%
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)

X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

print("X_train_tensor:", X_train_tensor.shape)
print("y_train_tensor:", y_train_tensor.shape)
# Out:
# X_train_tensor: torch.Size([232, 10, 1])
# y_train_tensor: torch.Size([232, 1])

# %%
class TimeSeriesDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
train_dataset = TimeSeriesDataset(X_train_tensor, y_train_tensor)
test_dataset = TimeSeriesDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=16,
    shuffle=False
)

# %%
class LSTMForecaster(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super().__init__()

        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True
        )

        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        # x shape:
        # (batch_size, sequence_length, input_size)

        out, (h_n, c_n) = self.lstm(x)

        # out shape:
        # (batch_size, sequence_length, hidden_size)

        # h_n shape:
        # (num_layers, batch_size, hidden_size)

        # c_n shape:
        # (num_layers, batch_size, hidden_size)

        # 取最后一个时间步的输出
        last_out = out[:, -1, :]

        # last_out shape:
        # (batch_size, hidden_size)

        pred = self.fc(last_out)

        return pred

# %%
input_size = 1
hidden_size = 32
num_layers = 1

model = LSTMForecaster(
    input_size=input_size,
    hidden_size=hidden_size,
    num_layers=num_layers
)

print(model)
# Out:
# LSTMForecaster(
#   (lstm): LSTM(1, 32, batch_first=True)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
epochs = 100

train_losses = []

for epoch in range(epochs):
    model.train()

    epoch_loss = 0

    for batch_X, batch_y in train_loader:
        # 前向传播
        pred = model(batch_X)

        # 计算损失
        loss = criterion(pred, batch_y)

        # 清空梯度
        optimizer.zero_grad()

        # 反向传播
        loss.backward()

        # 更新参数
        optimizer.step()

        epoch_loss += loss.item()

    avg_loss = epoch_loss / len(train_loader)
    train_losses.append(avg_loss)

    if (epoch + 1) % 10 == 0:
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {avg_loss:.4f}")
# Out:
# Epoch [10/100], Loss: 1.4396
# Epoch [20/100], Loss: 0.2338
# Epoch [30/100], Loss: 0.3074
# Epoch [40/100], Loss: 0.2017
# Epoch [50/100], Loss: 0.2508
# Epoch [60/100], Loss: 0.1915
# Epoch [70/100], Loss: 0.4269
# Epoch [80/100], Loss: 0.2350
# Epoch [90/100], Loss: 0.1815
# Epoch [100/100], Loss: 0.2038

# %%
plt.figure(figsize=(8, 4))
plt.plot(train_losses)
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.plot(train_losses)
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.grid(True)
plt.show()

# %%
model.eval()

with torch.no_grad():
    y_pred = model(X_test_tensor)

print("预测结果 shape:", y_pred.shape)
print("真实结果 shape:", y_test_tensor.shape)
# Out:
# 预测结果 shape: torch.Size([58, 1])
# 真实结果 shape: torch.Size([58, 1])

# %%
y_pred_np = y_pred.numpy().flatten()
y_test_np = y_test_tensor.numpy().flatten()

print("前 10 个预测值：")
print(y_pred_np[:10])

print("前 10 个真实值：")
print(y_test_np[:10])
# Out:
# 前 10 个预测值：
# [6.125501  6.24003   6.43135   6.132472  6.0504646 6.2022815 6.370047
#  6.8814454 7.0251603 6.8875985]
# 前 10 个真实值：
# [6.4546027 6.554206  5.9654512 6.295897  6.362494  6.4525933 7.3521976
#  7.1426406 6.8593597 7.739923 ]

# %%
plt.figure(figsize=(10, 4))
plt.plot(y_test_np, label="True")
plt.plot(y_pred_np, label="Predicted")
plt.title("LSTM Time Series Forecasting")
plt.xlabel("Test Time Step")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
mse = np.mean((y_test_np - y_pred_np) ** 2)
rmse = np.sqrt(mse)
mae = np.mean(np.abs(y_test_np - y_pred_np))

print("MSE:", mse)
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# MSE: 1.1396581
# RMSE: 1.0675477
# MAE: 0.87655854

# %%
last_window = series[-window_size:]

print("最后 10 个时间点：")
print(last_window)
# Out:
# 最后 10 个时间点：
# [9.63043597 9.57885846 9.54409777 9.93162795 9.70434028 9.27886513
#  9.62073561 9.28839162 9.27399655 9.0493692 ]

# %%
last_window_tensor = torch.tensor(
    last_window.reshape(1, window_size, 1),
    dtype=torch.float32
)

print("last_window_tensor shape:", last_window_tensor.shape)
# Out:
# last_window_tensor shape: torch.Size([1, 10, 1])

# %%
model.eval()

with torch.no_grad():
    next_pred = model(last_window_tensor)

print("预测下一个时间点的值：", next_pred.item())
# Out:
# 预测下一个时间点的值： 7.724907398223877

# %%
hidden_sizes = [8, 16, 32, 64]

for hs in hidden_sizes:
    temp_model = LSTMForecaster(
        input_size=1,
        hidden_size=hs,
        num_layers=1
    )

    temp_criterion = nn.MSELoss()
    temp_optimizer = torch.optim.Adam(temp_model.parameters(), lr=0.01)

    for epoch in range(50):
        temp_model.train()

        for batch_X, batch_y in train_loader:
            pred = temp_model(batch_X)
            loss = temp_criterion(pred, batch_y)

            temp_optimizer.zero_grad()
            loss.backward()
            temp_optimizer.step()

    temp_model.eval()

    with torch.no_grad():
        temp_pred = temp_model(X_test_tensor)

    temp_pred_np = temp_pred.numpy().flatten()
    temp_mse = np.mean((y_test_np - temp_pred_np) ** 2)

    print(f"hidden_size = {hs}, Test MSE = {temp_mse:.4f}")
# Out:
# hidden_size = 8, Test MSE = 1.2283
# hidden_size = 16, Test MSE = 0.8392
# hidden_size = 32, Test MSE = 0.8018
# hidden_size = 64, Test MSE = 0.7175

# %%
num_layers_list = [1, 2, 3]

for nl in num_layers_list:
    temp_model = LSTMForecaster(
        input_size=1,
        hidden_size=32,
        num_layers=nl
    )

    temp_criterion = nn.MSELoss()
    temp_optimizer = torch.optim.Adam(temp_model.parameters(), lr=0.01)

    for epoch in range(50):
        temp_model.train()

        for batch_X, batch_y in train_loader:
            pred = temp_model(batch_X)
            loss = temp_criterion(pred, batch_y)

            temp_optimizer.zero_grad()
            loss.backward()
            temp_optimizer.step()

    temp_model.eval()

    with torch.no_grad():
        temp_pred = temp_model(X_test_tensor)

    temp_pred_np = temp_pred.numpy().flatten()
    temp_mse = np.mean((y_test_np - temp_pred_np) ** 2)

    print(f"num_layers = {nl}, Test MSE = {temp_mse:.4f}")
# Out:
# num_layers = 1, Test MSE = 1.3834
# num_layers = 2, Test MSE = 1.6044
# num_layers = 3, Test MSE = 18.6164
